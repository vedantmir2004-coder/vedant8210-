# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url ="http://quotes.toscrape.com"

response = requests.get(url)

if response.status_code == 200:
    print("Website Connected Successfully!")
else:
    print("Failed to Connect")


soup = BeautifulSoup(response.text, "html.parser")

quotes = soup.find_all("div", class_="quote")

data = []


for quote in quotes:

    text = quote.find("span", class_="text").text
    author = quote.find("small", class_="author").text
    tags = quote.find ("div", class_="tags").get_text(strip=True)
    data.append([text, author, tags])

df = pd.DataFrame(data, columns = ["Quote", "Author", "Tags"])

df.to_csv("quotes_scrapping.csv", index=False)


print("successfully data scrapped")

print(df.head())
# Out:
# Website Connected Successfully!
# successfully data scrapped
#                                                Quote           Author  \
# 0  “The world as we have created it is a process ...  Albert Einstein
# 1  “It is our choices, Harry, that show what we t...     J.K. Rowling
# 2  “There are only two ways to live your life. On...  Albert Einstein
# 3  “The person, be it gentleman or lady, who has ...      Jane Austen
# 4  “Imperfection is beauty, madness is genius and...   Marilyn Monroe
#
#                                         Tags
# 0      Tags:changedeep-thoughtsthinkingworld
# 1                      Tags:abilitieschoices
# 2  Tags:inspirationallifelivemiraclemiracles
# 3            Tags:aliteracybooksclassichumor
# 4              Tags:be-yourselfinspirational
